# %%
#| default_exp Tutorial

# %%
#| hide
from nbdev.showdoc import *

# %% [markdown]
# ## How to use

# %% [markdown]
# 1. Download a demo dataset from [here](https://drive.google.com/drive/folders/1v-0Y_xNaec4OhzOqzwE8L2Wng8Cn-_vq?usp=share_link)
# 2. Import libraries

# %%
from esploco import esploco
# from espresso import espresso
import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# Hint: to see the function signature of any function or method, type function?

# %%
# esploco.esploco?

# %%
# esplocoPath='/Users/sangyuxu/esploco demo'
# e = espresso(esplocoPath, expt_duration_minutes=120)
# ele = esploco.esploco(esplocoPath, 0, 120, companionEspObj = e)
# Out:
# countLog files found:
#
# ['CountLog_2019-04-03_12-01-45.csv' 'CountLog_2019-04-27_17-20-05.csv']
#
# metaData files found:
#
# ['MetaData_2019-04-03_12-01-45.csv' 'MetaData_2019-04-03_12-01-47.csv'
#  'MetaData_2019-04-27_17-20-05.csv']
# portLocations files found:
#
# ['PortLocations_2019-04-03_12-01-47.csv'
#  'PortLocations_2019-04-27_17-20-05.csv']
#
# feedLog files found:
#
# ['FeedLog_2019-04-03_12-01-47.csv' 'FeedLog_2019-04-27_17-20-05.csv']
# CountLog_2019-04-03_12-01-45.csv
# MetaData_2019-04-03_12-01-45.csv
# CountLog_2019-04-27_17-20-05.csv
# MetaData_2019-04-27_17-20-05.csv

# %% [markdown]
# ## Calculate peri-feed speeds

# %%
# ele.calculatePeriFeedSpeed(e, monitorWindow=120)
# Out:
# recalculating feed duration for feeds...
#
# [--------------------------------------------------------------------]
# putting feeds back into countlog...
#
# [-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------]
# plotting PeriFeedDiagonal
# plotting pairedSpeedPlots
# dabest version = 2024.03.29

# %% [markdown]
# ## Calculate falls

# %%
# ele.calculateFallEvents()
# Out:
# Detecting Fall Events...
#
# [------------------------------------------------------------]
# Done

# %%
# ele.resultsDf.columns
# Out:
# Index(['ChamberID', 'Starved hrs', 'MealSizePerFly_µL',
#        'AverageFeedSpeedPerFly_µl/s', 'startMonitorIdx', 'startFeedIdx',
#        'startFeedIdxRevised', 'endFeedIdx', 'endFeedIdxRevised',
#        'endMonitorIdx', 'MeanSpeed120sBeforeFeed_mm/s',
#        'MeanSpeedDuringFeed_mm/s', 'MeanSpeed120sAfterFeed_mm/s',
#        'MeanMealDurationPerFly_s', 'AviFile', 'ExperimentState', 'Tube1',
#        'AverageFeedVolumePerFly_µl', 'AverageFeedCountPerFly',
#        'AverageFeedDurationPerFly_min', 'FeedVol_pl', 'Latency_min',
#        'duringBeforeSpeedRatio', 'afterBeforeSpeedRatio', 'ID', 'Status',
#        'Genotype', 'Sex', 'MinimumAge', 'MaximumAge', 'Food1', 'Food2',
#        'Temperature', '#Flies', 'Starvedhrs', 'Date', 'averageSpeed_mm/s',
#        'xPosition_mm', 'yPosition_mm', 'inLeftPort', 'inRightPort',
#        'countLogDate', 'feedLogDate', 'falls'],
#       dtype='object')

# %% [markdown]
# ## Stacked plot for feeds and other metrics

# %%
# Fstacked, feeds_sorted, colorBy = ele.plotStacked(endMin = 120, 
#                           colorBy = ['Status', 'Temperature'], 
#                           metricsToStack = ['Volume', 'Speed'], 
#                           figsize = None,
#                           plotNonFeeders=False, 
#                           showRasterYticks=True, 
#                          ylimPresets = None)

## consult the function signature for different configurations of input arguments

# %% [markdown]
# ## Plotting small multiples

# %%
# ele.plotChamberSmallMultiples()
# Out:
# Espresso Runs found:
#
# ['2021-09-16_10-55-50' '2021-09-20_15-39-12']
#
#
#  plotting 2021-09-16_10-55-50...
#
#
#  plotting 2021-09-20_15-39-12...
# (array([<Figure size 1000x200 with 30 Axes>,
#         <Figure size 1000x200 with 30 Axes>], dtype=object),
#  array([<Figure size 1000x200 with 30 Axes>,
#         <Figure size 1000x200 with 30 Axes>], dtype=object))

# %% [markdown]
# ## Mean heat maps

# %% [markdown]
# ### Plot mean heatmaps with seconds as unit

# %%
# meanheatmaps = ele.plotMeanHeatMaps(row = 'Status', col = 'Temperature')

# %% [markdown]
# ### Plot mean heatmaps with z-score

# %%
# meanheatmaps = ele.plotMeanHeatMaps(row = 'Status', col = 'Temperature', plotZScore = True)

# %% [markdown]
# ### Plot mean heatmaps with arbitrary vmin and vmax

# %%
# meanheatmaps = ele.plotMeanHeatMaps(row = 'Status', col = 'Temperature', plotZScore = True, vmin = 0.2, vmax = 0.6)

# %% [markdown]
# ## Ribbon Plots

# %%
# ribbonplot = ele.plotBoundedLines(locoSuffix = 'V', col = 'Temperature', colorBy = 'Status')

# %% [markdown]
# ## Contrast plots
#
# ### Contrast plots can be made for any of the metrics in .resultsDf:
#
# * 'MeanSpeed120sBeforeFeed_mm/s',
# * 'MeanSpeedDuringFeed_mm/s',
# * 'MeanSpeed120sAfterFeed_mm/s',
# * 'MeanMealDurationPerFly_s',
# * 'AverageFeedVolumePerFly_µl',
# * 'AverageFeedCountPerFly',
# * 'AverageFeedDuration_min',
# * 'MealSizePerFly_µL',
# * 'AverageFeedSpeedPerFly_µl/s',
# * 'FeedVol_pl',
# * 'Latency_min',
# * 'duringBeforeSpeedRatio',
# * 'afterBeforeSpeedRatio',
# * 'averageSpeed_mm/s',
# * 'xPosition_mm',
# * 'yPosition_mm',
# * 'inLeftPort',
# * 'inRightPort',
#
# ### The following other fields in .resultsDf can be used as independent variables.
#
# * 'ChamberID',
# * 'Starved hrs',
# * 'ID',
# * 'Status',
# * 'Genotype',
# * 'Sex',
# * 'MinimumAge',
# * 'MaximumAge',
# * 'Food1',
# * 'Food2',
# * 'Temperature',
# * '#Flies',
# * 'Starvedhrs',
# * 'Date',
# * 'countLogDate',
# * 'feedLogDate'

# %%
# import dabest
# print(dabest.__version__)

# contrast = dabest.load(data = ele.resultsDf, 
#                        x = ['Temperature', 'Genotype'], 
#                        y = 'AverageFeedVolumePerFly_µl', 
#                        experiment = 'Status', x1_level=['Red Light Off', 'Red Light On'] , delta2 = True)
# f = contrast.mean_diff.plot()
# f.axes[0].set_xticklabels(['Ctrl Off', 'Ctrl On', 'Test Off', 'Test On'])
# f.axes[1].set_xticklabels(['', 'Ctrl Δ', '', 'Test Δ', '', 'ΔΔ'])
# Out:
# 2023.02.14
# [Text(0, 0, ''),
#  Text(1, 0, 'Ctrl Δ'),
#  Text(2, 0, ''),
#  Text(3, 0, 'Test Δ'),
#  Text(4, 0, ''),
#  Text(5, 0, 'ΔΔ')]
